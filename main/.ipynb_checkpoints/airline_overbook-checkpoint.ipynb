# %%
import pandas as pd
import numpy as np
import os
import pandas.io.sql as pd_sql
import psycopg2 as pg
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path='C:/Users/anar.baylarov/Desktop/anar/Github/airlines/main'
os.chdir(path)
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B05C-7CB8
#
#  Directory of C:\Users\anar.baylarov\Desktop\anar\Github\airlines\main
#
# 21.04.2020  21:11    <DIR>          .
# 21.04.2020  21:11    <DIR>          ..
# 21.04.2020  19:37    <DIR>          .ipynb_checkpoints
# 21.04.2020  21:11            10.179 airline_overbook.ipynb
# 21.04.2020  21:06    <DIR>          istdsa
#                1 File(s)         10.179 bytes
#                4 Dir(s)  170.248.474.624 bytes free

# %%
host='aws_host_info'
connection_args = {
    'host': host,
    'dbname': 'airlines',
    'user': 'ubuntu',
    'port': 5432
}

# %%
connection = pg.connect(**connection_args)
query='select * from final_airlines_data;'
df_orj=pd_sql.read_sql(query, connection)
df_orj.sample(5,random_state=125)
# Out:
#         departures_scheduled  departures_performed    payload  seats  \
# 207216                  11.0                  11.0   450570.0   1760
# 232507                  87.0                  86.0  4184022.0  14534
# 231018                  72.0                   5.0   260200.0    900
# 182548                  77.0                  76.0  2499320.0  11324
# 406184                  62.0                  59.0  2206600.0   8946
#
#         passengers  freight      mail  distance  ramp_to_ramp  air_time  ...  \
# 207216        1521    870.0    3423.0     447.0        1075.0     775.0  ...
# 232507       13308  15872.0  117937.0    2454.0       30318.0   27375.0  ...
# 231018         879    445.0    1119.0    1426.0         933.0     840.0  ...
# 182548        8076   1034.0       0.0     352.0        5979.0    4320.0  ...
# 406184        7851      0.0       0.0    1072.0       10375.0    9042.0  ...
#
#         year quarter  month seats_v1  passengers_v1 null_seats  \
# 207216  2015       2      6      160            138         22
# 232507  2015       2      6      169            155         14
# 231018  2015       3      8      180            176          4
# 182548  2014       4     11      149            106         43
# 406184  2019       1      3      152            133         19
#
#         null_seats_prop  day_per_departures_perf  distance_grouped  \
# 207216             0.14                     0.37                 0
# 232507             0.08                     2.87                 4
# 231018             0.02                     0.17                 3
# 182548             0.29                     2.53                 0
# 406184             0.13                     1.97                 2
#
#         is_overbooked
# 207216              1
# 232507              1
# 231018              0
# 182548              1
# 406184              1
#
# [5 rows x 27 columns]

# %%
df_orj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408739 entries, 0 to 408738
# Data columns (total 27 columns):
# departures_scheduled       408739 non-null float64
# departures_performed       408739 non-null float64
# payload                    408739 non-null float64
# seats                      408739 non-null int64
# passengers                 408739 non-null int64
# freight                    408739 non-null float64
# mail                       408739 non-null float64
# distance                   408739 non-null float64
# ramp_to_ramp               408739 non-null float64
# air_time                   408739 non-null float64
# unique_carrier             408739 non-null object
# unique_carrier_name        408739 non-null object
# origin_airport_id          408739 non-null int64
# origin                     408739 non-null object
# dest_airport_id            408739 non-null int64
# dest                       408739 non-null object
# aircraft_type              408739 non-null int64
# year                       408739 non-null int64
# quarter                    408739 non-null int64
# month                      408739 non-null int64
# seats_v1                   408739 non-null int64
# passengers_v1              408739 non-null int64
# null_seats                 408739 non-null int64
# null_seats_prop            408739 non-null float64
# day_per_departures_perf    408739 non-null float64
# distance_grouped           408739 non-null int64
# is_overbooked              408739 non-null int64
# dtypes: float64(10), int64(13), object(4)
# memory usage: 84.2+ MB

# %%
df_1=df_orj[['departures_scheduled', 'departures_performed', 'seats',
       'passengers', 'distance', 'air_time',
       'unique_carrier', 'origin_airport_id',
       'dest_airport_id', 'aircraft_type', 'year', 'month',
       'seats_v1', 'passengers_v1', 'null_seats', 'null_seats_prop',
       'day_per_departures_perf', 'distance_grouped', 'is_overbooked']].copy()

# %%
# object veri tipindeki unique_carrrier`e encode uygulanarak kodlandı
df_1['unique_carrier']=df_1.unique_carrier.astype('category').cat.codes

# %%
df_1.groupby(['is_overbooked']).count()['seats']
# Out:
# is_overbooked
# 0    147669
# 1    261070
# Name: seats, dtype: int64

# %%
df_1.describe()
# Out:
#        departures_scheduled  departures_performed          seats  \
# count         408739.000000         408739.000000  408739.000000
# mean              32.874274             31.091344    4774.199978
# std               41.691919             40.031618    6372.744139
# min                0.000000              0.000000       0.000000
# 25%                4.000000              4.000000     504.000000
# 50%               23.000000             21.000000    3000.000000
# 75%               43.000000             40.000000    6169.000000
# max              533.000000            533.000000   94391.000000
#
#           passengers       distance       air_time  unique_carrier  \
# count  408739.000000  408739.000000  408739.000000   408739.000000
# mean     4007.524026    1083.726194    4338.749026        1.346627
# std      5492.098344     694.509135    6452.994326        0.653592
# min         0.000000       3.000000       0.000000        0.000000
# 25%       417.000000     546.000000     420.500000        1.000000
# 50%      2384.000000     948.000000    2176.000000        1.000000
# 75%      5180.000000    1517.000000    5747.000000        2.000000
# max     85361.000000    5674.000000  180007.000000        2.000000
#
#        origin_airport_id  dest_airport_id  aircraft_type           year  \
# count      408739.000000    408739.000000  408739.000000  408739.000000
# mean        12646.142883     12638.905208     662.576696    2014.679916
# std          1513.496165      1515.013965      51.259718       2.544332
# min         10135.000000     10135.000000     359.000000    2010.000000
# 25%         11292.000000     11292.000000     622.000000    2013.000000
# 50%         12478.000000     12478.000000     655.000000    2015.000000
# 75%         13930.000000     13930.000000     694.000000    2017.000000
# max         16218.000000     16218.000000     889.000000    2019.000000
#
#                month       seats_v1  passengers_v1     null_seats  \
# count  408739.000000  408739.000000  408739.000000  408739.000000
# mean        6.414952     147.747587     121.364668      26.382919
# std         3.518836      43.497060      41.776160      22.154566
# min         1.000000       0.000000       0.000000       0.000000
# 25%         3.000000     126.000000     102.000000      12.000000
# 50%         6.000000     150.000000     123.000000      21.000000
# 75%         9.000000     166.000000     143.000000      34.000000
# max        12.000000     403.000000     402.000000     352.000000
#
#        null_seats_prop  day_per_departures_perf  distance_grouped  \
# count    408739.000000            408739.000000     408739.000000
# mean          0.172655                 1.036063          1.798852
# std           0.135669                 1.334599          1.314558
# min           0.000000                 0.000000          0.000000
# 25%           0.080000                 0.130000          1.000000
# 50%           0.140000                 0.700000          2.000000
# 75%           0.230000                 1.330000          3.000000
# max           1.000000                17.770000          4.000000
#
#        is_overbooked
# count  408739.000000
# mean        0.638721
# std         0.480372
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
plt.figure(figsize=(13,8))
sns.countplot(data=df_1[['year','is_overbooked']],x='year',hue='is_overbooked')

# %%
# 2019un outlier değer olduğunu tespit ettik
flt_1=df_1['year']==2019
df_1[flt_1].groupby(['month']).count()['is_overbooked'].sort_values(ascending=False)
# Out:
# month
# 1    4449
# 3    4389
# 4    4104
# 2    3456
# Name: is_overbooked, dtype: int64

# %%
flt_2=df_1['year']!=2019
df_2=df_1[flt_2].copy()
df_2.tail(3)
# Out:
#         departures_scheduled  departures_performed  seats  passengers  \
# 408736                  49.0                  49.0   4900        3684
# 408737                  49.0                  49.0   4900        4261
# 408738                  50.0                   0.0      0           0
#
#         distance  air_time  unique_carrier  origin_airport_id  \
# 408736     313.0    2544.0               0              11278
# 408737     541.0    3980.0               0              11057
# 408738    1028.0       0.0               1              12478
#
#         dest_airport_id  aircraft_type  year  month  seats_v1  passengers_v1  \
# 408736            10529            678  2016      9       100             75
# 408737            12478            678  2016     11       100             87
# 408738            14027            819  2016      1         0              0
#
#         null_seats  null_seats_prop  day_per_departures_perf  \
# 408736          25             0.25                     1.63
# 408737          13             0.13                     1.63
# 408738           0             0.00                     0.00
#
#         distance_grouped  is_overbooked
# 408736                 0              1
# 408737                 1              1
# 408738                 2              0

# %%
plt.figure(figsize=(13,8))
sns.countplot(data=df_2[['month','is_overbooked']],x='month',hue='is_overbooked')

# %%
df_2['unique_carrier'].value_counts()
# Out:
# 1    178960
# 2    173797
# 0     39584
# Name: unique_carrier, dtype: int64

# %%
'''
modellerimizi etkilemeyecek olan alanları belirleyerek verisetimizden çıkardık:
''' 
df_2.drop(['year','unique_carrier','air_time'],axis=1,inplace=True)
df_2.head(3)
# Out:
#    departures_scheduled  departures_performed  seats  passengers  distance  \
# 0                  66.0                   0.0      0           0    2172.0
# 1                  54.0                  53.0   7950        6799    1562.0
# 2                  55.0                  55.0   5500        4837     818.0
#
#    origin_airport_id  dest_airport_id  aircraft_type  month  seats_v1  \
# 0              14057            10397            622      3         0
# 1              10721            11298            694      3       150
# 2              10721            10994            678      5       100
#
#    passengers_v1  null_seats  null_seats_prop  day_per_departures_perf  \
# 0              0           0             0.00                     0.00
# 1            128          22             0.15                     1.77
# 2             88          12             0.12                     1.83
#
#    distance_grouped  is_overbooked
# 0                 4              0
# 1                 3              1
# 2                 1              1

# %%
mapping={'seats_v1':'seats_per_departure',
        'passengers_v1':'passengers_per_departure',
        'null_seats':'empty_seats_per_departure',
        'null_seats_prop':'empty_seats_proportion',
        'day_per_departures_perf':'departures_per_day'}
df_2.rename(columns=mapping,inplace=True)
df_2.head(3)
# Out:
#    departures_scheduled  departures_performed  seats  passengers  distance  \
# 0                  66.0                   0.0      0           0    2172.0
# 1                  54.0                  53.0   7950        6799    1562.0
# 2                  55.0                  55.0   5500        4837     818.0
#
#    origin_airport_id  dest_airport_id  aircraft_type  month  \
# 0              14057            10397            622      3
# 1              10721            11298            694      3
# 2              10721            10994            678      5
#
#    seats_per_departure  passengers_per_departure  empty_seats_per_departure  \
# 0                    0                         0                          0
# 1                  150                       128                         22
# 2                  100                        88                         12
#
#    empty_seats_proportion  departures_per_day  distance_grouped  is_overbooked
# 0                    0.00                0.00                 4              0
# 1                    0.15                1.77                 3              1
# 2                    0.12                1.83                 1              1

# %%
def calc_per(a,b):
    try:
        result=round(a/b,2)
    except ZeroDivisionError:
        result=0
    return(result)

# %%
df_2['distance_per_departure']=calc_per(df_2.distance,df_2.departures_performed)
df_2.distance_per_departure.replace([np.inf,-np.inf],np.nan,inplace=True)
df_2[['distance','departures_performed','distance_per_departure']].head()
# Out:
#    distance  departures_performed  distance_per_departure
# 0    2172.0                   0.0                     NaN
# 1    1562.0                  53.0                   29.47
# 2     818.0                  55.0                   14.87
# 3     502.0                  55.0                    9.13
# 4    1237.0                  57.0                   21.70

# %%
df_2.dropna(axis=0,inplace=True)
df_2.drop(['departures_scheduled','departures_performed','seats','passengers','distance'],axis=1,inplace=True)
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 377360 entries, 1 to 408737
# Data columns (total 12 columns):
# origin_airport_id            377360 non-null int64
# dest_airport_id              377360 non-null int64
# aircraft_type                377360 non-null int64
# month                        377360 non-null int64
# seats_per_departure          377360 non-null int64
# passengers_per_departure     377360 non-null int64
# empty_seats_per_departure    377360 non-null int64
# empty_seats_proportion       377360 non-null float64
# departures_per_day           377360 non-null float64
# distance_grouped             377360 non-null int64
# is_overbooked                377360 non-null int64
# distance_per_departure       377360 non-null float64
# dtypes: float64(3), int64(9)
# memory usage: 37.4 MB

# %%
df_2.head(3)
# Out:
#    origin_airport_id  dest_airport_id  aircraft_type  month  \
# 1              10721            11298            694      3
# 2              10721            10994            678      5
# 3              11433            12953            608      7
#
#    seats_per_departure  passengers_per_departure  empty_seats_per_departure  \
# 1                  150                       128                         22
# 2                  100                        88                         12
# 3                  110                        99                         11
#
#    empty_seats_proportion  departures_per_day  distance_grouped  \
# 1                    0.15                1.77                 3
# 2                    0.12                1.83                 1
# 3                    0.10                1.83                 1
#
#    is_overbooked  distance_per_departure
# 1              1                   29.47
# 2              1                   14.87
# 3              1                    9.13
